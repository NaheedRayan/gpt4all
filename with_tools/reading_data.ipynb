# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Step 3: Read CSV File
file_path = "/home/naheed/Desktop/gpt4all/with_tools/archive/test.csv"
df = pd.read_csv(file_path)

# %%
df["new"]=""
# df
df.to_csv(file_path , index=False)
df = pd.read_csv(file_path)
df
# Out:
#                                                     url  \
# 0               http://www.freebase.com/view/en/jamaica
# 1          http://www.freebase.com/view/en/james_k_polk
# 2          http://www.freebase.com/view/en/oregon_ducks
# 3            http://www.freebase.com/view/en/ken_barlow
# 4       http://www.freebase.com/view/en/chiune_sugihara
# ...                                                 ...
# 2027      http://www.freebase.com/view/en/david_beckham
# 2028             http://www.freebase.com/view/en/france
# 2029            http://www.freebase.com/view/en/knossos
# 2030  http://www.freebase.com/view/en/roswell_ufo_in...
# 2031  http://www.freebase.com/view/en/christopher_riley
#
#                                                question  \
# 0                      what does jamaican people speak?
# 1     what did james k polk do before he was president?
# 2      what is the oregon ducks 2012 football schedule?
# 3            who plays ken barlow in coronation street?
# ...
