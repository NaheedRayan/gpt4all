# %%
import csv
import pandas as pd

# %%
df = pd.read_csv("llmdataset3.csv")
print(df.to_string())
# Out:
#     Unnamed: 0.1  Unnamed: 0                                                                                                                                                             Question                                                              Answer  True/False  Result
# 0              0           0                                                                                                                                  who got Nobel Prize 2023 in Peace ?                                                      Sheaikh hasina       False     NaN
# 1              1           1                                                                                                             who got The Nobel Prize in Physiology or Medicine 2023 ?                                      Drew Weissman & Katalin Karikó        True     NaN
# 2              2           2                                                                                                                                      who won 2023 Cricket World Cup?                                                           Australia        True     NaN
# 3              3           3                                                                                                           Who is the player of the series in 2023 Cricket World Cup?                                                      Sakib al Hasan       False     NaN
# 4              4           4                                                                                                                  How many teams are their in 2023 Cricket World Cup?                                                                  10        True     NaN
# 5              5           5                                                                                                             Bangladesh won how many match in 2023 Cricket World Cup?                                                                   2        True     NaN
# 6              6           6                                                                                 Is any Bangladeshi teenager nominated for International Children's Peace Prize 2023?                                                        Mainul Islam        True     NaN
# 7              7           7                                                                                                                      Who was the interim CEO to lead OpenAI in 2023?                                                         Mira Murati        True     NaN
# 8              8           8                                                                                                   When the  Khawaja Tower in Dhaka's Mohakhali Fire brokout in 2023?                                                             Evening        True     NaN
# 9              9           9                                                                                                                               When was Dhaka Metro Rail inaugurated?                                                           29-Dec-22        True     NaN
# 10            10          10                                                                                                                    \nWhat is the slogan of metro rail in Bangladesh?                           Moving People Saving Time and Environment        True     NaN
# 11            11          11                                                                                                                           Is metro rail off on Friday in bangladesh?                                                                 Yes        True     NaN
# 12            12          12                                                                                                                          \nWho inaugurated metro rail in bangladesh?                                        Prime Minister Sheikh Hasina        True     NaN
# 13            13          13                                                                                                                                       \nWho funded Bangladesh metro?                    Japanese International Cooperation Agency (JICA)        True     NaN
# 14            14          14                                                                                                                                         Leo indian film release date                                                           19-Oct-23        True     NaN
# 15            15          15                                                                                                                              Leo Hollywood film release date netflix                                             November 17, 2023 (USA)        True     NaN
# 16            16          16                                                               The protagonist of the movie Zom 100: Bucket List of the Dead is Akira Tendo what it is his real name?                                       He is portrayed by Eiji Akaso        True     NaN
# 17            17          17                                                                                                        which Republican lawmaker got expelled from US House in 2023?                                                       George Santos        True     NaN
# 18            18          18                                                                                              what is the Magnitude of earthquake in december 2nd 2023 at bangladesh?                                            Magnitude 5.5 earthquake        True     NaN
# 19            19          19                                                                           When did the earthquake take place at Ramganj, Chittagong, Bangladesh, on December 2,2023?                                                             9:35 AM        True     NaN
# 20            20          20                                    Are there any initial reports of damage or casualties from the earthquake at Ramganj, Chittagong, Bangladesh, on December 2,2023?                                                                  No        True     NaN
# 21            21          21                                                                                      In which division did the earthquake occur  in december 2nd 2023 at bangladesh?                                                 Chittagong Division        True     NaN
# 22            22          22                                                                    Where did the earthquake occur in relation to Ramganj, Chittagong Division  in december 2nd 2023?                                    Around 9 km (5 miles) northeast.        True     NaN
# 23            23          23                                                                            Who won the opening Test between Bangladesh and New Zealand in Sylhet in 2023 bangladesh?                                                          Bangladesh        True     NaN
# 24            24          24                                                                           Who was the standout bowler for Bangladesh in the opening Test in bd vs nz match in 2023 ?                                                        Taijul Islam        True     NaN
# 25            25          25                                                                                           When are the general elections scheduled to be held in Bangladesh in 2024?                                                            7-Jan-24        True     NaN
# 26            26          26                                                                   What caused disruption in internet and telecom services in Dhaka's Mohakhali in 2023 for few days?        Fire at Khawaja Tower, housing IIGs, data centers, and ICXs.        True     NaN
# 27            27          27                                                               Why will mobile internet and voice connections be impacted by the disruption in Fire at Khawaja Tower?                   Mobile services get bandwidth from affected IIGs.        True     NaN
# 28            28          28                                                                           What does ICX stand for, and what function does it serve in the telecommunication network?                            ICX stands for Interconnection Exchanges        True     NaN
# 29            29          29                                                                      What was the year-on-year increase in remittance sent home by migrant workers in November 2023?                                                          21 percent        True     NaN
# 30            30          30                                                   How much did migrant workers send home in November 2023, and how does it compare to the same month last year 2022?                        $1.93 billion,an increase from $1.59 billion        True     NaN
# 31            31          31                                                                                What is the current trend in remittance receipts compared to the previous month 2023?  November's receipts were 2.42 percent down from the previous month        True     NaN
# 32            32          32  How many garment workers were injured during the earthquake  incident in Chauddagram, Cumilla, and what caused the rush to exit the factory building december 2023?                                                          76 workers        True     NaN
# 33            33          33                                                     Taijul Islam takes how many wickets in the first Test at the Sylhet International Cricket Stadium november 2023?                                                                  10        True     NaN

# %%
df['Question'][0]

type(df['Question'][0])

df["Result"] = None


# dropping a column
# df.drop('result' , axis=1 , inplace=True)
# df.drop('Unnamed: 0' , axis=1 , inplace=True)
# df.drop('Unnamed: 0.1' , axis=1 , inplace=True)

# print(df.to_string())

df
# Out:
#                                              Question  \
# 0                 who got Nobel Prize 2023 in Peace ?
# 1   who got The Nobel Prize in Physiology or Medic...
# 2                     who won 2023 Cricket World Cup?
# 3   Who is the player of the series in 2023 Cricke...
# 4   How many teams are their in 2023 Cricket World...
# 5   Bangladesh won how many match in 2023 Cricket ...
# 6   Is any Bangladeshi teenager nominated for Inte...
# 7     Who was the interim CEO to lead OpenAI in 2023?
# 8   When the  Khawaja Tower in Dhaka's Mohakhali F...
# 9              When was Dhaka Metro Rail inaugurated?
# 10  \nWhat is the slogan of metro rail in Bangladesh?
# 11         Is metro rail off on Friday in bangladesh?
# 12        \nWho inaugurated metro rail in bangladesh?
# 13                     \nWho funded Bangladesh metro?
# 14                       Leo indian film release date
# 15            Leo Hollywood film release date netflix
# 16  The protagonist of the movie Zom 100: Bucket L...
# 17  which Republican lawmaker got expelled from US...
# 18  what is the Magnitude of earthquake in decembe...
# 19  When did the earthquake take place at Ramganj,...
# 20  Are there any initial reports of damage or cas...
# 21  In which division did the earthquake occur  in...
# 22  Where did the earthquake occur in relation to ...
# 23  Who won the opening Test between Bangladesh an...
# 24  Who was the standout bowler for Bangladesh in ...
# 25  When are the general elections scheduled to be...
# 26  What caused disruption in internet and telecom...
# 27  Why will mobile internet and voice connections...
# 28  What does ICX stand for, and what function doe...
# 29  What was the year-on-year increase in remittan...
# 30  How much did migrant workers send home in Nove...
# 31  What is the current trend in remittance receip...
# 32  How many garment workers were injured during t...
# 33  Taijul Islam takes how many wickets in the fir...
#
#                                                Answer  True/False Result
# 0                                      Sheaikh hasina       False   None
# 1                      Drew Weissman & Katalin Karikó        True   None
# 2                                           Australia        True   None
# 3                                      Sakib al Hasan       False   None
# 4                                                  10        True   None
# 5                                                   2        True   None
# 6                                        Mainul Islam        True   None
# 7                                         Mira Murati        True   None
# 8                                             Evening        True   None
# 9                                           29-Dec-22        True   None
# 10          Moving People Saving Time and Environment        True   None
# 11                                                Yes        True   None
# 12                       Prime Minister Sheikh Hasina        True   None
# 13   Japanese International Cooperation Agency (JICA)        True   None
# 14                                          19-Oct-23        True   None
# 15                            November 17, 2023 (USA)        True   None
# 16                      He is portrayed by Eiji Akaso        True   None
# 17                                      George Santos        True   None
# 18                           Magnitude 5.5 earthquake        True   None
# 19                                            9:35 AM        True   None
# 20                                                 No        True   None
# 21                                Chittagong Division        True   None
# 22                   Around 9 km (5 miles) northeast.        True   None
# 23                                         Bangladesh        True   None
# 24                                       Taijul Islam        True   None
# 25                                           7-Jan-24        True   None
# 26  Fire at Khawaja Tower, housing IIGs, data cent...        True   None
# 27  Mobile services get bandwidth from affected IIGs.        True   None
# 28           ICX stands for Interconnection Exchanges        True   None
# 29                                         21 percent        True   None
# 30       $1.93 billion,an increase from $1.59 billion        True   None
# 31  November's receipts were 2.42 percent down fro...        True   None
# 32                                         76 workers        True   None
# 33                                                 10        True   None

# %%
# iterating dataframe
# for i  in len(df["Result"]):
#     print(i)

# for some warning
pd.options.mode.chained_assignment = None  # default='warn'

for i in range(len(df['Result'])):
    df['Result'][i] = None

df

df.to_csv("llmdataset3.csv" , index=False)
df = pd.read_csv("llmdataset3.csv")
df
# Out:
#                                              Question  \
# 0                 who got Nobel Prize 2023 in Peace ?
# 1   who got The Nobel Prize in Physiology or Medic...
# 2                     who won 2023 Cricket World Cup?
# 3   Who is the player of the series in 2023 Cricke...
# 4   How many teams are their in 2023 Cricket World...
# 5   Bangladesh won how many match in 2023 Cricket ...
# 6   Is any Bangladeshi teenager nominated for Inte...
# 7     Who was the interim CEO to lead OpenAI in 2023?
# 8   When the  Khawaja Tower in Dhaka's Mohakhali F...
# 9              When was Dhaka Metro Rail inaugurated?
# 10  \nWhat is the slogan of metro rail in Bangladesh?
# 11         Is metro rail off on Friday in bangladesh?
# 12        \nWho inaugurated metro rail in bangladesh?
# 13                     \nWho funded Bangladesh metro?
# 14                       Leo indian film release date
# 15            Leo Hollywood film release date netflix
# 16  The protagonist of the movie Zom 100: Bucket L...
# 17  which Republican lawmaker got expelled from US...
# 18  what is the Magnitude of earthquake in decembe...
# 19  When did the earthquake take place at Ramganj,...
# 20  Are there any initial reports of damage or cas...
# 21  In which division did the earthquake occur  in...
# 22  Where did the earthquake occur in relation to ...
# 23  Who won the opening Test between Bangladesh an...
# 24  Who was the standout bowler for Bangladesh in ...
# 25  When are the general elections scheduled to be...
# 26  What caused disruption in internet and telecom...
# 27  Why will mobile internet and voice connections...
# 28  What does ICX stand for, and what function doe...
# 29  What was the year-on-year increase in remittan...
# 30  How much did migrant workers send home in Nove...
# 31  What is the current trend in remittance receip...
# 32  How many garment workers were injured during t...
# 33  Taijul Islam takes how many wickets in the fir...
#
#                                                Answer  True/False  Result
# 0                                      Sheaikh hasina       False     NaN
# 1                      Drew Weissman & Katalin Karikó        True     NaN
# 2                                           Australia        True     NaN
# 3                                      Sakib al Hasan       False     NaN
# 4                                                  10        True     NaN
# 5                                                   2        True     NaN
# 6                                        Mainul Islam        True     NaN
# 7                                         Mira Murati        True     NaN
# 8                                             Evening        True     NaN
# 9                                           29-Dec-22        True     NaN
# 10          Moving People Saving Time and Environment        True     NaN
# 11                                                Yes        True     NaN
# 12                       Prime Minister Sheikh Hasina        True     NaN
# 13   Japanese International Cooperation Agency (JICA)        True     NaN
# 14                                          19-Oct-23        True     NaN
# 15                            November 17, 2023 (USA)        True     NaN
# 16                      He is portrayed by Eiji Akaso        True     NaN
# 17                                      George Santos        True     NaN
# 18                           Magnitude 5.5 earthquake        True     NaN
# 19                                            9:35 AM        True     NaN
# 20                                                 No        True     NaN
# 21                                Chittagong Division        True     NaN
# 22                   Around 9 km (5 miles) northeast.        True     NaN
# 23                                         Bangladesh        True     NaN
# 24                                       Taijul Islam        True     NaN
# 25                                           7-Jan-24        True     NaN
# 26  Fire at Khawaja Tower, housing IIGs, data cent...        True     NaN
# 27  Mobile services get bandwidth from affected IIGs.        True     NaN
# 28           ICX stands for Interconnection Exchanges        True     NaN
# 29                                         21 percent        True     NaN
# 30       $1.93 billion,an increase from $1.59 billion        True     NaN
# 31  November's receipts were 2.42 percent down fro...        True     NaN
# 32                                         76 workers        True     NaN
# 33                                                 10        True     NaN
